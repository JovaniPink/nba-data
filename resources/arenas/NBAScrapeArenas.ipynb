# %% [markdown]
# # Arena Scraper

# %% [markdown]
# ## Import Deps

# %%
# %config IPCompleter.greedy=True

# https://docs.python.org/3/library/datetime.html
import datetime as dt

# https://docs.python.org/3/howto/regex.html
import re

# https://beautiful-soup-4.readthedocs.io/en/latest/
from bs4 import BeautifulSoup as bs

# https://splinter.readthedocs.io/en/latest/#
from splinter import Browser

# %% [markdown]
# ## Using Splinter to Download HTML
#
# But first you want to check when the last time the splinter code was last ran.

# %%
import pathlib
from os import scandir


def convert_date(timestamp):
    d = dt.datetime.utcfromtimestamp(timestamp)
    formated_date = d.strftime("%d %b %Y")
    return formated_date


file = pathlib.Path("arena.html")
if file.exists():
    info = file.stat()
    print(f"File already exists and last updated on {convert_date(info.st_mtime)}")
else:
    # Using Splinter to automate the browser actions
    # Initiate headless driver for deployment
    with Browser("chrome", executable_path="chromedriver", headless=True) as browser:
        # Visit URL
        url = "https://en.wikipedia.org/wiki/List_of_National_Basketball_Association_arenas"
        browser.visit(url)

        list_of_arena_a_tags = browser.find_by_css("a[class='image']")
        print(list_of_arena_a_tags.first.value)

        # I know the current URL I've passed to visit
        # is the site that holds all the logos I am looking for
        # so I just save the site and start working with bs4

        # Scrape page into soup
        html = browser.html

        # Save HTML to local machine so we don't continue to requests
        with open("arena.html", "w", encoding="utf8") as f:
            f.write(html)

# browser = Browser("chrome", executable_path="chromedriver", headless=True)

# %%
# current HTMl file
# opened_html = ""

# Read in local HTML page
with open("arena.html", "r", encoding="UTF-8", errors="strict") as f:
    opened_html = f.read()

    # Scrape page into soup
    soup = bs(opened_html, "html.parser")

    # Print out the html structure to plan out the scraping logic
    # print(soup.prettify())

    # I want to find all the table tags and filter down to a specfic table with arena data
    list_of_table_tags = soup.find_all("table")
    wanted_table = list_of_table_tags[0]
    list_of_arena_images = wanted_table.find_all("a", {"class": "image"})

    clean_url_list_bs4 = []
    for i in list_of_arena_images:
        temp = i.get("href")
        clean_url_list_bs4.append(temp)

# %% [markdown]
# ## Using Pandas

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_html.html
import pandas as pd

areans_df = pd.read_html(
    "https://en.wikipedia.org/wiki/List_of_National_Basketball_Association_arenas",
    match="Arena",
)
print(len(areans_df))
# Out:
# 10

# %%
print(areans_df)
# Out:
# [    Image                       Arena                    Location  \
# 0     NaN             Amalie Arena[a]              Tampa, Florida
# 1     NaN     American Airlines Arena              Miami, Florida
# 2     NaN    American Airlines Center               Dallas, Texas
# 3     NaN                Amway Center            Orlando, Florida
# 4     NaN                 AT&T Center          San Antonio, Texas
# 5     NaN                  Ball Arena            Denver, Colorado
# 6     NaN     Bankers Life Fieldhouse       Indianapolis, Indiana
# 7     NaN             Barclays Center          Brooklyn, New York
# 8     NaN           Capital One Arena            Washington, D.C.
# 9     NaN                Chase Center   San Francisco, California
# 10    NaN     Chesapeake Energy Arena     Oklahoma City, Oklahoma
# 11    NaN                  FedExForum          Memphis, Tennessee
# 12    NaN                Fiserv Forum        Milwaukee, Wisconsin
# 13    NaN             Golden 1 Center      Sacramento, California
# 14    NaN        Little Caesars Arena           Detroit, Michigan
# 15    NaN       Madison Square Garden     New York City, New York
# 16    NaN                 Moda Center            Portland, Oregon
# 17    NaN          Phoenix Suns Arena            Phoenix, Arizona
# 18    NaN  Rocket Mortgage FieldHouse             Cleveland, Ohio
# 19    NaN         Scotiabank Arena[a]            Toronto, Ontario
# 20    NaN        Smoothie King Center      New Orleans, Louisiana
# 21    NaN             Spectrum Center   Charlotte, North Carolina
# 22    NaN              Staples Center     Los Angeles, California
# 23    NaN              Staples Center     Los Angeles, California
# 24    NaN            State Farm Arena            Atlanta, Georgia
# 25    NaN               Target Center      Minneapolis, Minnesota
# 26    NaN                   TD Garden       Boston, Massachusetts
# 27    NaN               Toyota Center              Houston, Texas
# 28    NaN               United Center           Chicago, Illinois
# 29    NaN     Vivint Smart Home Arena        Salt Lake City, Utah
# 30    NaN          Wells Fargo Center  Philadelphia, Pennsylvania
#
#                    Team(s)  Capacity   Opened       Ref(s)
# 0          Toronto Raptors     20500     1996          [2]
# 1               Miami Heat     19600     1999       [3][4]
# 2         Dallas Mavericks     19200     2001       [3][5]
# 3            Orlando Magic     18846     2010       [3][6]
# 4        San Antonio Spurs     18418     2002       [3][7]
# 5           Denver Nuggets     19520     1999       [3][8]
# 6           Indiana Pacers     17923     1999       [3][9]
# 7            Brooklyn Nets     17732     2012      [3][10]
# 8       Washington Wizards     20356     1997      [3][11]
# 9    Golden State Warriors     18064     2019  [3][12][13]
# 10   Oklahoma City Thunder     18203     2002      [3][14]
# 11       Memphis Grizzlies     17794     2004      [3][15]
# 12         Milwaukee Bucks     17500     2018      [3][16]
# 13        Sacramento Kings     17583     2016      [3][17]
# 14         Detroit Pistons     20332     2017      [3][18]
# 15         New York Knicks     19812  1968[b]      [3][19]
# 16  Portland Trail Blazers     19441     1995      [3][20]
# 17            Phoenix Suns     18055     1992      [3][21]
# 18     Cleveland Cavaliers     19432     1994  [3][22][23]
# 19         Toronto Raptors     19800     1999      [3][24]
# 20    New Orleans Pelicans     16867     1999      [3][25]
# 21       Charlotte Hornets     19077     2005      [3][26]
# 22    Los Angeles Clippers     19068     1999      [3][27]
# 23      Los Angeles Lakers     18997     1999      [3][27]
# 24           Atlanta Hawks     18118     1999      [3][28]
# 25  Minnesota Timberwolves     18978     1990      [3][29]
# 26          Boston Celtics     18624     1995      [3][30]
# 27         Houston Rockets     18055     2003      [3][31]
# 28           Chicago Bulls     20917     1994      [3][32]
# 29               Utah Jazz     18306     1991      [3][33]
# 30      Philadelphia 76ers     20478     1996  [3][34][35]  ,                                            Arena                  Team  \
# 0  Inglewood Basketball and Entertainment Center  Los Angeles Clippers
#
#                 Location  Capacity  Opening     Reference
# 0  Inglewood, California     18000     2024  [36][37][38]  ,                        0                                                  1  \
# 0     Eastern Conference                                 Eastern Conference
# 1      Atlantic Division                                  Atlantic Division
# 2               Team[39]                                              Arena
# 3         Boston Celtics                                                NaN
# 4         Boston Celtics      Hartford Civic CenterXL Center (2007–present)
# ..                   ...                                                ...
# 66        Indiana Pacers  Indiana State Fairgrounds ColiseumIndiana Farm...
# 67       Milwaukee Bucks                                                NaN
# 68       Milwaukee Bucks  Bradley Center BMO Harris Bradley Center (2012...
# 69       Milwaukee Bucks  MECCA Arena (1974–1995)UW–Milwaukee Panther Ar...
# 70  Milwaukee, Wisconsin                                                NaN
#
#                                          2                   3  \
# 0                       Eastern Conference  Eastern Conference
# 1                        Atlantic Division   Atlantic Division
# 2                               Years used            Capacity
# 3                                      NaN                 NaN
# 4   1975–1995(occasionally for home games)               16294
# ..                                     ...                 ...
# 66                               1967–1974               10000
# 67                                     NaN                 NaN
# 68                               1988–2018               18717
# 69                1968–19882017 (one game)               10783
# 70                                     NaN                 NaN
#
#                      4                      5                   6
# 0   Eastern Conference     Eastern Conference  Eastern Conference
# 1    Atlantic Division      Atlantic Division   Atlantic Division
# 2               Opened               Location                Ref.
# 3                  NaN                    NaN                 NaN
# 4                 1975  Hartford, Connecticut            [40][41]
# ..                 ...                    ...                 ...
# 66                1939  Indianapolis, Indiana               [102]
# 67                 NaN                    NaN                 NaN
# 68                1988   Milwaukee, Wisconsin          [103][104]
# 69                1950   Milwaukee, Wisconsin               [105]
# 70                 NaN                    NaN                 NaN
#
# [71 rows x 7 columns],                                                     0  \
# 0                                  Western Conference
# 1                                  Southwest Division
# 2                                                Team
# 3                                    Dallas Mavericks
# 4                                    Dallas Mavericks
# ..                                                ...
# 67  Sacramento KingsKansas City KingsKansas City-O...
# 68  Sacramento KingsKansas City KingsKansas City-O...
# 69  Sacramento KingsKansas City KingsKansas City-O...
# 70  Sacramento KingsKansas City KingsKansas City-O...
# 71  Sacramento KingsKansas City KingsKansas City-O...
#
#                                                     1  \
# 0                                  Western Conference
# 1                                  Southwest Division
# 2                                               Arena
# 3                                                 NaN
# 4                                       Reunion Arena
# ..                                                ...
# 67                             Omaha Civic Auditorium
# 68                               Municipal Auditorium
# 69                                 Cincinnati Gardens
# 70  Rochester Community War MemorialBlue Cross Are...
# 71                                Edgerton Park Arena
#
#                               2                   3                   4  \
# 0            Western Conference  Western Conference  Western Conference
# 1            Southwest Division  Southwest Division  Southwest Division
# 2                    Years used            Capacity              Opened
# 3                           NaN                 NaN                 NaN
# 4                     1980–2001               18293                1980
# ..                          ...                 ...                 ...
# 67  1972–1978(partial schedule)                9300                1954
# 68                    1972–1974                9287                1936
# 69                    1957–1972               11000                1949
# 70                    1955–1957               12428                1955
# 71                    1945–1955                4200                1892
#
#                         5                   6
# 0      Western Conference  Western Conference
# 1      Southwest Division  Southwest Division
# 2                Location                Ref.
# 3                     NaN                 NaN
# 4           Dallas, Texas               [106]
# ..                    ...                 ...
# 67        Omaha, Nebraska               [146]
# 68  Kansas City, Missouri          [147][148]
# 69       Cincinnati, Ohio               [149]
# 70    Rochester, New York          [144][150]
# 71    Rochester, New York               [150]
#
# [72 rows x 7 columns],                                                  Team  \
# 0      Anderson Packers (1946–1950; 1949–1950 in NBA)
# 1                       Baltimore Bullets (1944–1954)
# 2                            Chicago Stags(1946–1950)
# 3                        Cleveland Rebels (1946–1947)
# 4                           Denver Nuggets(1948–1950)
# 5                          Detroit Falcons(1946–1947)
# 6   Indianapolis JetsIndianapolis Kautskys(1948–1949)
# 7                   Indianapolis Olympians(1949–1953)
# 8                      Pittsburgh Ironmen (1946–1947)
# 9                  Providence Steamrollers(1946–1949)
# 10             Sheboygan RedskinsEnzo Jels(1938–1951)
# 11             Sheboygan RedskinsEnzo Jels(1938–1951)
# 12                      St. Louis Bombers (1946–1950)
# 13                         Toronto Huskies(1946–1947)
# 14                     Washington Capitols(1946–1951)
# 15                         Waterloo Hawks (1948–1951)
#
#                                             Arena Years used Capacity  \
# 0                                      The Wigwam  1949–1950     8996
# 1                              Baltimore Coliseum  1944–1954     4500
# 2                                 Chicago Stadium  1946–1950    18676
# 3                                 Cleveland Arena  1946–1947    10000
# 4                                Auditorium Arena  1948–1950    12000
# 5                                 Detroit Olympia  1946–1947  Unknown
# 6                               Hinkle Fieldhouse  1948–1949    15000
# 7                               Hinkle Fieldhouse  1949–1953    15000
# 8                                Duquesne Gardens  1946–1947     6500
# 9                         Rhode Island Auditorium  1946–1949     5300
# 10      Sheboygan Municipal Auditorium and Armory  1942–1951     3500
# 11                               Eagle Auditorium  1938–1942     1200
# 12     St. Louis ArenaThe Checkerdome (1977–1983)  1946–1950    15000
# 13                             Maple Leaf Gardens  1946–1947    15000
# 14  Uline ArenaWashington Coliseum (1959–present)  1946–1951     7000
# 15                             McElroy Auditorium  1948–1951     5155
#
#      Opened                  Location             Ref.
# 0      1925         Anderson, Indiana  [151][152][153]
# 1      1930       Baltimore, Maryland            [154]
# 2      1929         Chicago, Illinois       [155][156]
# 3      1937           Cleveland, Ohio            [157]
# 4      1908          Denver, Colorado            [158]
# 5      1927         Detroit, Michigan  [159][160][161]
# 6      1928     Indianapolis, Indiana            [162]
# 7      1928     Indianapolis, Indiana            [163]
# 8      1890  Pittsburgh, Pennsylvania            [164]
# 9      1926  Providence, Rhode Island            [165]
# 10     1942      Sheboygan, Wisconsin            [166]
# 11  Unknown      Sheboygan, Wisconsin            [166]
# 12     1929       St. Louis, Missouri            [167]
# 13     1931          Toronto, Ontario            [168]
# 14     1941          Washington, D.C.  [169][170][171]
# 15     1936            Waterloo, Iowa            [172]  ,                                    0                           1  \
# 0                     Neutral Venues              Neutral Venues
# 1                              Arena                    Location
# 2                   Duquesne Gardens    Pittsburgh, Pennsylvania
# 3                        Civic Arena    Pittsburgh, Pennsylvania
# 4            Charleston Civic Center   Charleston, West Virginia
# 5                 Mid-South Coliseum          Memphis, Tennessee
# 6                  Curtis Hixon Hall              Tampa, Florida
# 7        Greensboro Coliseum Complex  Greensboro, North Carolina
# 8                St. Paul Auditorium       Saint Paul, Minnesota
# 9  ESPN Wide World of Sports Complex           Bay Lake, Florida
#
#                                                    2               3  \
# 0                                     Neutral Venues  Neutral Venues
# 1                                               Date      Attendance
# 2                                     March 11, 1953             NaN
# 3  February 18, 1964December 14, 1964January 11, ...             NaN
# 4                  December 6, 1965February 14, 1966             NaN
# 5  December 19, 1966December 26, 1966January 2, 1...             NaN
# 6                                   January 16, 1967             NaN
# 7                                   January 30, 1967            7168
# 8                                   February 7, 1967             NaN
# 9                           July 30–October 11, 2020             NaN
#
#                                 4
# 0                  Neutral Venues
# 1                       Reference
# 2                      [173][174]
# 3  [173][175][176][177][178][179]
# 4                      [180][181]
# 5                      [182][183]
# 6                      [182][184]
# 7                      [183][185]
# 8                      [182][186]
# 9                           [187]  ,   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteCurrent arenas in the National Basketball Association  \
# 0                                 Eastern Conference
# 1                                           Atlantic
# 2                                            Central
# 3                                          Southeast
# 4                                 Western Conference
# 5                                          Northwest
# 6                                            Pacific
# 7                                          Southwest
#
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteCurrent arenas in the National Basketball Association.1
# 0  Atlantic Amalie Arena Barclays Center Madison ...
# 1  Amalie Arena Barclays Center Madison Square Ga...
# 2  Bankers Life Fieldhouse Fiserv Forum Little Ca...
# 3  American Airlines Arena Amway Center Capital O...
# 4  Northwest Ball Arena Chesapeake Energy Arena M...
# 5  Ball Arena Chesapeake Energy Arena Moda Center...
# 6  Chase Center Golden 1 Center Phoenix Suns Aren...
# 7  American Airlines Center AT&T Center FedExForu...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ,            0                                                  1
# 0   Atlantic  Amalie Arena Barclays Center Madison Square Ga...
# 1    Central  Bankers Life Fieldhouse Fiserv Forum Little Ca...
# 2  Southeast  American Airlines Arena Amway Center Capital O...,            0                                                  1
# 0  Northwest  Ball Arena Chesapeake Energy Arena Moda Center...
# 1    Pacific  Chase Center Golden 1 Center Phoenix Suns Aren...
# 2  Southwest  American Airlines Center AT&T Center FedExForu...,    vteNational Basketball Association  \
# 0                   EasternConference
# 1                            Atlantic
# 2                             Central
# 3                           Southeast
# 4                   WesternConference
# 5                           Northwest
# 6                             Pacific
# 7                           Southwest
# 8                       Annual events
# 9                             History
# 10                             People
# 11                  Awards and honors
# 12                             Others
# 13            Category 2020–21 season
#
#                  vteNational Basketball Association.1
# 0   Atlantic Boston Celtics Brooklyn Nets New York...
# 1   Boston Celtics Brooklyn Nets New York Knicks P...
# 2   Chicago Bulls Cleveland Cavaliers Detroit Pist...
# 3   Atlanta Hawks Charlotte Hornets Miami Heat Orl...
# 4   Northwest Denver Nuggets Minnesota Timberwolve...
# 5   Denver Nuggets Minnesota Timberwolves Oklahoma...
# 6   Golden State Warriors Los Angeles Clippers Los...
# 7   Dallas Mavericks Houston Rockets Memphis Grizz...
# 8   Draft Eligibility Summer League Christmas Day ...
# 9   Predecessors BAA NBL ABA Merger Criticisms and...
# 10  Players Current rosters Foreign players Race a...
# 11  Larry O'Brien Trophy NBA awards MVP Finals MVP...
# 12  Arenas Business Collective bargaining agreemen...
# 13                            Category 2020–21 season  ]

# %%
import time

# Initiate headless driver for deployment
browser = Browser("chrome", executable_path="chromedriver", headless=True)

# Visit URL
url = "https://en.wikipedia.org/wiki/List_of_National_Basketball_Association_arenas"
browser.visit(url)

list_of_arena_a_tags = browser.find_by_css("a[class='image']")

original_url_list_splinter = []
for i in list_of_arena_a_tags:
    original_url_list_splinter.append(i["href"])

clean_url_list_splinter = []
for x in original_url_list_splinter:
    # Find the Original file link and click that
    browser.visit(x)
    browser.is_element_present_by_text("Original file", wait_time=5)
    more_info_elem = browser.find_by_css("a[class='internal']")
    clean_url_list_splinter.append(more_info_elem["href"])

# Stop webdriver and return data
browser.quit()

print(clean_url_list_splinter)
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/5/58/Chase_Center_-_East_Side_-_San_Francisco.jpg', 'https://upload.wikimedia.org/wikipedia/commons/2/2a/St_Pete_Times_Forum_At_Sunset.jpg', 'https://upload.wikimedia.org/wikipedia/commons/4/44/American_Airlines_Arena%2C_Miami%2C_FL%2C_jjron_29.03.2012.jpg', 'https://upload.wikimedia.org/wikipedia/commons/b/bc/American_Airlines_Center_August_2015.jpg', 'https://upload.wikimedia.org/wikipedia/commons/9/9f/Amway_Center.jpg', 'https://upload.wikimedia.org/wikipedia/commons/5/50/Texasdd.JPG', 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Denver_Pepsi_Center_1.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/67/Bankers_Life_Fieldhouse%2C_Indian%C3%A1polis%2C_Estados_Unidos%2C_2012-10-22%2C_DD_02.jpg', 'https://upload.wikimedia.org/wikipedia/commons/5/55/Barclays_Center_western_side.jpg', 'https://upload.wikimedia.org/wikipedia/commons/7/7f/Verizon_Center_wide.jpg', 'https://upload.wikimedia.org/wikipedia/commons/5/58/Chase_Center_-_East_Side_-_San_Francisco.jpg', 'https://upload.wikimedia.org/wikipedia/commons/2/2e/Chesapeake_Energy_Arena_2017.jpg', 'https://upload.wikimedia.org/wikipedia/commons/3/37/FedExForum.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/68/Wisconsin_Entertainment_and_Sports_Center_-_Northeast_view.jpg', 'https://upload.wikimedia.org/wikipedia/commons/0/0c/Golden_1_Center_2017.jpg', 'https://upload.wikimedia.org/wikipedia/commons/f/f3/Little_Caesars_Arena_panorama.jpg', 'https://upload.wikimedia.org/wikipedia/commons/d/dc/Madison_Square_Garden%2C_February_2013.jpg', 'https://upload.wikimedia.org/wikipedia/commons/7/74/Moda_Center.JPG', 'https://upload.wikimedia.org/wikipedia/commons/9/91/Talking_Stick_Resort_Arena.JPG', 'https://upload.wikimedia.org/wikipedia/commons/4/46/Quicken_Loans_Arena_4.jpg', 'https://upload.wikimedia.org/wikipedia/commons/5/57/Scotiabank_Arena_-_2018_%28cropped%29.jpg', 'https://upload.wikimedia.org/wikipedia/commons/0/00/Smoothie_King_Center.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/6e/Spectrum_Center_2018.jpg', 'https://upload.wikimedia.org/wikipedia/commons/2/24/Staples_Center_2012.jpg', 'https://upload.wikimedia.org/wikipedia/commons/f/fa/Philips_Arena.jpg', 'https://upload.wikimedia.org/wikipedia/commons/a/a7/TargetCenter.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/6a/TD_Garden_%28crop%29.JPG', 'https://upload.wikimedia.org/wikipedia/commons/d/db/Toyota_Center_entr.jpg', 'https://upload.wikimedia.org/wikipedia/commons/4/47/United_Center_060716.jpg', 'https://upload.wikimedia.org/wikipedia/commons/1/17/Vivint_Smart_Home_Arena_August_13%2C_2016.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/61/Wells_Fargo_Center.jpg', 'https://upload.wikimedia.org/wikipedia/commons/d/da/NBA_arenas.jpg']

# %% [markdown]
# ## Download Images with Request

# %%
## Importing Necessary Modules
# https://requests.readthedocs.io/en/master/
# https://docs.python.org/3/library/shutil.html#module-shutil
import shutil  # to save it locally

import requests  # to get image from the web

counter = 1
# Looping through the img_url_list and downloading
for i in clean_url_list_splinter:
    counter = counter + 1
    response = requests.get(i, stream=True)
    if response.status_code == 200:
        response.raw.decode_content = True

        with open(f"{str(counter)}.jpg", "wb") as f:
            shutil.copyfileobj(response.raw, f)
        
        print(f"Image sucessfully Downloaded: {str(counter)}")
    
    else:
        print("Image Couldn't be retreived")
# Out:
# Image sucessfully Downloaded: 2
# Image sucessfully Downloaded: 3
# Image sucessfully Downloaded: 4
# Image sucessfully Downloaded: 5
# Image sucessfully Downloaded: 6
# Image sucessfully Downloaded: 7
# Image sucessfully Downloaded: 8
# Image sucessfully Downloaded: 9
# Image sucessfully Downloaded: 10
# Image sucessfully Downloaded: 11
# Image sucessfully Downloaded: 12
# Image sucessfully Downloaded: 13
# Image sucessfully Downloaded: 14
# Image sucessfully Downloaded: 15
# Image Couldn't be retreived
# Image Couldn't be retreived
# Image Couldn't be retreived
# Image Couldn't be retreived
# Image sucessfully Downloaded: 20
# Image Couldn't be retreived
# Image Couldn't be retreived
# Image Couldn't be retreived
# Image sucessfully Downloaded: 24
# Image sucessfully Downloaded: 25
# Image sucessfully Downloaded: 26
# Image Couldn't be retreived
# Image Couldn't be retreived
# Image sucessfully Downloaded: 29
# Image Couldn't be retreived
# Image Couldn't be retreived
# Image sucessfully Downloaded: 32
# Image sucessfully Downloaded: 33

# %%
# Out:
# []
